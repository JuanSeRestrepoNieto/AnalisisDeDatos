# %%
import pandas as pd

# %%
df = pd.read_csv('../data/clean/AirBnbDataClean.csv')

df.head()
# Out:
#    Unnamed: 0       id                                              NAME  \
# 0           0  1001254                Clean & quiet apt home by the park
# 1           1  1002102                             Skylit Midtown Castle
# 2           4  1003689  Entire Apt: Spacious Studio/Loft by central park
# 3           5  1004098         Large Cozy 1 BR Apartment In Midtown East
# 4           7  1005202                                   BlissArtsSpace!
#
#        host id host_identity_verified host name neighbourhood group  \
# 0  80014485718            unconfirmed  Madaline            Brooklyn
# 1  52335172823               verified     Jenna           Manhattan
# 2  92037596077               verified    Lyndon           Manhattan
# 3  45498551794               verified  Michelle           Manhattan
# 4  90821839709            unconfirmed      Emma            Brooklyn
#
#         neighbourhood       lat      long  ...  Construction year   price  \
# ...

# %% [markdown]
# # Tendencia central

# %%
def media(data):
  n = len(data)
  sum = 0
  for i in data:
    sum += i
  return sum / n

def mediana(data):
  n = len(data)
