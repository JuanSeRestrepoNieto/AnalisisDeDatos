# %%
import pandas as pd

# %%
df = pd.read_csv('../data/clean/AirBnbDataClean.csv')

df.describe()
# Out:
#           Unnamed: 0            id       host id           lat          long  \
# count   84313.000000  8.431300e+04  8.431300e+04  84313.000000  84313.000000
# mean    52118.434180  2.959593e+07  4.917181e+10     40.727354    -73.948504
# std     29525.742692  1.620379e+07  2.853124e+10      0.056344      0.050358
# min         0.000000  1.001254e+06  1.236005e+08     40.504560    -74.249840
# 25%     26333.000000  1.547601e+07  2.443182e+10     40.687670    -73.982110
# 50%     54295.000000  3.082830e+07  4.900886e+10     40.721330    -73.953720
# 75%     77082.000000  4.327824e+07  7.383948e+10     40.762610    -73.930830
# max    102597.000000  5.735803e+07  9.876313e+10     40.916970    -73.705220
#
#        Construction year         price   service fee  minimum nights  \
# count       84313.000000  84313.000000  84313.000000    84313.000000
# mean         2012.485951    626.042710    125.209588        7.428665
# ...

# %% [markdown]
# # Tendencia central

# %%
def media(data):
  n = len(data)
  sum = 0
  for i in data:
    sum += i
  return sum / n

def mediana(data):
  n = len(data)
